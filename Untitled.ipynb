# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("vgsales.csv")
data.head(10)
data.shape
data = data.dropna()

# %%
data['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
data['Publisher'].nunique()
# Out:
# 578

# %%
data.groupby("Genre").head(8)
# Out:
#      Rank                               Name Platform    Year         Genre  \
# 0       1                         Wii Sports      Wii  2006.0        Sports
# 1       2                  Super Mario Bros.      NES  1985.0      Platform
# 2       3                     Mario Kart Wii      Wii  2008.0        Racing
# 3       4                  Wii Sports Resort      Wii  2009.0        Sports
# 4       5           Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ..    ...                                ...      ...     ...           ...
# 434   435  Club Penguin: Elite Penguin Force       DS  2008.0     Adventure
# 447   448                         Heavy Rain      PS3  2010.0     Adventure
# 511   512       Command & Conquer: Red Alert       PC  1996.0      Strategy
# 547   548                  Pokémon Stadium 2      N64  2000.0      Strategy
# 578   579                          Halo Wars     X360  2009.0      Strategy
#
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data['Publisher'].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# SCS Software                       1
# Piacci                             1
# Max Five                           1
# Fields                             1
# MediaQuest                         1
# Name: Publisher, Length: 578, dtype: int64

# %%
data['Platform'].value_counts().head(1)
# Out:
# DS    2163
# Name: Platform, dtype: int64

# %%
mg = data.Global_Sales.max()
data.query('Global_Sales==@mg')
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
data.groupby(['Genre', 'Global_Sales', 'Year']).agg('Global_Sales', 'max')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-a19b8409e148> in <module>
# ----> 1 data.groupby(['Genre', 'Global_Sales', 'Year']).agg('Global_Sales', 'max')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# --> 928         result, how = self._aggregate(func, *args, **kwargs)
#     929         if how is None:
#     930             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     309
#     310         if isinstance(arg, str):
# --> 311             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     312
#     313         if isinstance(arg, dict):
#
# ...

# %%
data.groupby(['Genre', 'Year']).agg({'Global_Sales':'max'})
# Out:
#                  Global_Sales
# Genre    Year
# Action   1980.0          0.34
#          1981.0          2.20
#          1982.0          0.66
#          1983.0          0.77
#          1984.0          1.85
# ...                       ...
# Strategy 2012.0          0.72
#          2013.0          1.67
#          2014.0          0.37
#          2015.0          0.51
#          2016.0          0.20
#
# [389 rows x 1 columns]

# %%
data.groupby(['Genre', 'Year']).agg({'Global_Sales':'min'})
# Out:
#                  Global_Sales
# Genre    Year
# Action   1980.0          0.34
#          1981.0          0.17
#          1982.0          0.14
#          1983.0          0.17
#          1984.0          1.85
# ...                       ...
# Strategy 2012.0          0.01
#          2013.0          0.02
#          2014.0          0.03
#          2015.0          0.01
#          2016.0          0.01
#
# [389 rows x 1 columns]
